# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import csv

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ## Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url ="http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
print("Beginning Data Retrieval")
print("-----------------------------")
weather=[]
i=0
for city in cities:
    time.sleep(1)
    i=i+1
    response= requests.get(query_url+city).json()
    print(f"Processing Record {i} of set {len(cities)} |{city}")
    weather.append(response)
    

  
print("-----------------------------")
print("Data Retrieval Complete")  
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 626 |tuktoyaktuk
# Processing Record 2 of set 626 |mataura
# Processing Record 3 of set 626 |gorontalo
# Processing Record 4 of set 626 |calamar
# Processing Record 5 of set 626 |yellowknife
# Processing Record 6 of set 626 |turtas
# Processing Record 7 of set 626 |chokurdakh
# Processing Record 8 of set 626 |attawapiskat
# Processing Record 9 of set 626 |lebu
# Processing Record 10 of set 626 |busselton
# Processing Record 11 of set 626 |ancud
# Processing Record 12 of set 626 |pueblo nuevo
# Processing Record 13 of set 626 |vaini
# Processing Record 14 of set 626 |ushuaia
# Processing Record 15 of set 626 |new norfolk
# Processing Record 16 of set 626 |east london
# Processing Record 17 of set 626 |leeton
# Processing Record 18 of set 626 |alibag
# Processing Record 19 of set 626 |punta alta
# Processing Record 20 of set 626 |neryungri
# Processing Record 21 of set 626 |kahului
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
City=[]
Lat=[]
Lng=[]
Max_Temp=[]
Humidity=[]
Cloudiness=[]
Wind_Speed=[]
Country=[]
Date=[]
i=0
for city in cities:
    try:
        City.append(weather[i]['name'])
        Lat.append(weather[i]['coord']['lat'])
        Lng.append(weather[i]['coord']['lon'])
        Max_Temp.append(weather[i]['main']['temp_max'])
        Humidity.append(weather[i]['main']['humidity'])
        Cloudiness.append(weather[i]['clouds']['all'])
        Wind_Speed.append(weather[i]['wind']['speed'])
        Country.append(weather[i]['sys']['country'])
        Date.append(weather[i]['dt'])
    except: KeyError
    pass
    i=i+1



citi_weather=pd.DataFrame({
            'City':City,
            'Lat':Lat,
            'Lng':Lng,
            'Max Temp':Max_Temp,
            'Humidity':Humidity,
            'Cloudiness':Cloudiness,
            'Wind Speed':Wind_Speed,
            'Country':Country,
            'Date':Date
    
}) 


citi_weather.to_csv(output_data_file,encoding='utf-8', header='true', index=False)
citi_weather
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Tuktoyaktuk  69.4541 -133.0374     16.12        94         100
# 1        Mataura -46.1927  168.8643     46.96       100         100
# 2      Gorontalo   0.5412  123.0595     75.83        95          98
# 3        Calamar  10.2511  -74.9146     78.75        78          99
# 4    Yellowknife  62.4560 -114.3525     27.41        95          90
# ..           ...      ...       ...       ...       ...         ...
# 574       Itoman  26.1247  127.6694     66.97        90          75
# 575       Sorgun  39.8101   35.1860     55.02        26          49
# 576        Kieta  -6.2167  155.6333     79.75        78          94
# 577   Port Hardy  50.6996 -127.4199     44.98        86         100
# 578     Sisimiut  66.9395  -53.6735     10.78        79          44
#
#      Wind Speed Country        Date
# 0         10.25      CA  1636808017
# 1          1.12      NZ  1636808018
# 2          3.98      ID  1636807771
# ...

# %%
citi_weather.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  579.000000  579.000000  579.000000  579.000000  579.000000  579.000000
# mean    21.066134   13.630037   57.236546   70.613126   62.991364    7.590449
# std     33.147557   88.316742   25.074418   22.045853   38.727711    5.657588
# min    -54.800000 -179.166700  -24.320000    6.000000    0.000000    0.000000
# 25%     -5.553450  -63.730700   40.585000   58.000000   20.000000    3.635000
# 50%     25.700000   16.374200   62.940000   75.000000   79.000000    6.220000
# 75%     49.766800   92.134300   77.885000   88.000000  100.000000   10.180000
# max     78.218600  178.416700  101.390000  100.000000  100.000000   49.480000
#
#                Date
# count  5.790000e+02
# mean   1.636808e+09
# std    2.512856e+02
# min    1.636808e+09
# 25%    1.636808e+09
# 50%    1.636808e+09
# 75%    1.636809e+09
# max    1.636809e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
citi_weather.sort_values(by='Humidity', ascending=False)
#There is no cities humidity >100. There are some cities=100
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 29                  Timmins  48.4669  -81.3331     31.82       100
# 144               Marystown  47.1666  -55.1483     35.85       100
# 367  Santa Isabel Rio Negro  -0.4139  -65.0192     72.12       100
# 165                   Tiksi  71.6872  128.8694    -12.86       100
# 390                     Hue  16.4667  107.6000     69.91       100
# ..                      ...      ...       ...       ...       ...
# 368                Taywarah  33.3500   64.4167     48.74         9
# 445               Kimberley -28.7323   24.7623     87.33         8
# 96                    Kohlu  29.8962   69.2520     72.75         7
# 299                 Barkhan  29.8977   69.5256     73.76         7
# 351                     Gao  16.6362    1.6370     88.02         6
#
#      Cloudiness  Wind Speed Country        Date
# 29           75        5.75      CA  1636797328
# 144         100        6.60      CA  1636797798
# ...

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Capomulin.grouped=Capomulin.groupby("Mouse ID")
# average=Capomulin.grouped.mean()
plt.scatter(citi_weather["Lat"],citi_weather["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.title("City Latitude vs. Max Temperature(11/13/2021)")
plt.grid()
plt.savefig("output_data/lat_Temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(citi_weather["Lat"],citi_weather["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity(11/13/2021)")
plt.grid()
plt.savefig("output_data/lat_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(citi_weather["Lat"],citi_weather["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title("City Latitude vs. Cloundiness (11/13/2021)")
plt.savefig("output_data/lat_Cloudiness.png")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(citi_weather["Lat"],citi_weather["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.title("City Latitude vs. Wind Speed (11/13/2021)")
plt.grid()
plt.savefig("output_data/lat_Wind Speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
Northern_citi=citi_weather[citi_weather['Lat']>0]
Northern_citi
Southern_citi=citi_weather[citi_weather['Lat']<0]
Southern_citi
# Clean_combined_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 3           Atuona  -9.8000 -139.0333     77.38        71          34
# 4            Vaini -21.2000 -175.2000     75.36        94          40
# 5          Rikitea -23.1203 -134.9692     72.82        70          66
# 7           Moerai -22.4333 -151.3333     74.21        72         100
# 15           Bluff -46.6000  168.3333     48.99        88         100
# ..             ...      ...       ...       ...       ...         ...
# 540        Solwezi -12.1688   26.3894     88.39        27          27
# 541  Mbanza-Ngungu  -5.2500   14.8667     76.12        79         100
# 545         Trelew -43.2490  -65.3051     60.39        83         100
# 548   Keetmanshoop -26.5833   18.1333     88.86        13          94
# 551      Boyolangu  -8.1181  111.8935     79.36        80          94
#
#      Wind Speed Country        Date
# 3         14.34      PF  1636797587
# 4          6.91      TO  1636797588
# ...

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Northern_citi["Lat"]
y_values = Northern_citi["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7884796171809287

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Southern_citi["Lat"]
y_values = Southern_citi["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.31940963027728725

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Northern_citi["Lat"]
y_values = Northern_citi["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.16732817857914925

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Southern_citi["Lat"]
y_values = Southern_citi["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.028126386351823643

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Northern_citi["Lat"]
y_values = Northern_citi["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.05210078008182427

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Southern_citi["Lat"]
y_values = Southern_citi["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.09412486792751468

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Northern_citi["Lat"]
y_values = Northern_citi["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Northern Hemisphere-Wind Speed (mph) vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.010366971652630117

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Southern_citi["Lat"]
y_values = Southern_citi["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed)")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.04216356857909619
